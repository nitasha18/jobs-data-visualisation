# %%
# importing all necessery modules 
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 
# %matplotlib inline

# %%
import seaborn as sns

# %%
# Reads 'jobs.csv' file 
dfPune = pd.read_csv(r"Data Analyst-Pune-job-results.csv")
dfNDelhi = pd.read_csv(r"Data Analyst-New Delhi-job-results.csv")
dfBlr = pd.read_csv(r"Data Analyst-Bengaluru-job-results.csv")
dfHyd = pd.read_csv(r"Data Analyst-Hyderabad-job-results.csv")
dfNoida = pd.read_csv(r"Data Analyst-Noida-job-results.csv")
dfGur = pd.read_csv(r"Data Analyst-Gurgaon-job-results.csv")

# %%
dfPune.head()
# Out:
#    Unnamed: 0                      Name              Company  City Location  \
# 0           0              Data Analyst             Cotiviti  Pune     Pune
# 1           1  Data Information Analyst              Red Hat  Pune     Pune
# 2           2              Data Analyst       Merkle Sokrati  Pune     Pune
# 3           3              Data Analyst     Affinity Express  Pune     Pune
# 4           4              Data Analyst   Brave Venture Labs  Pune     Pune
#
#                                                  Url  \
# 0  https://www.glassdoor.com/partner/jobListing.h...
# 1  https://www.glassdoor.com/partner/jobListing.h...
# 2  https://www.glassdoor.com/partner/jobListing.h...
# 3  https://www.glassdoor.com/partner/jobListing.h...
# 4  https://www.glassdoor.com/partner/jobListing.h...
#
#                                             JOB_INFO
# 0  PRINCIPLE PURPOSE OF JOB .Financial Data Analy...
# 1  At Red Hat, we connect an innovative community...
# ...

# %%
comment_words = '' 
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in dfPune.JOB_INFO: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
dfBlr.head()
# Out:
#    Unnamed: 0                    Name   Company       City   Location  \
# 0           0  Data Solutions Analyst   Intrado  Bengaluru  Bengaluru
# 1           1            Data Analyst    Amazon  Bengaluru  Bengaluru
# 2           2            Data Analyst    Cyient  Bengaluru  Bengaluru
# 3           3            Data Analyst   Siemens  Bengaluru  Bengaluru
# 4           4            Data Analyst   Cargill  Bengaluru  Bengaluru
#
#                                                  Url  \
# 0  https://www.glassdoor.com/partner/jobListing.h...
# 1  https://www.glassdoor.com/partner/jobListing.h...
# 2  https://www.glassdoor.com/partner/jobListing.h...
# 3  https://www.glassdoor.com/partner/jobListing.h...
# 4  https://www.glassdoor.com/partner/jobListing.h...
#
#                                             JOB_INFO
# 0  BASIC FUNCTION .Responsible for utilizing a va...
# 1  Through the Amazon Marketplace, Amazon provide...
# 2  Cyient takes pride in partnering with the worl...
# ...

# %%
dfGur.head()
# Out:
#    Unnamed: 0                                           Name       Company  \
# 0           0             Business Analyst - Data Management       Genpact
# 1           1                            Junior Data Analyst   GroundTruth
# 2           2  Data Operations Analyst - Workforce Analytics           FIS
# 3           3                                   Data Analyst     TBO Group
# 4           4                                   Data Analyst        Adidas
#
#       City Location                                                Url  \
# 0  Gurgaon  Gurgaon  https://www.glassdoor.com/partner/jobListing.h...
# 1  Gurgaon  Gurgaon  https://www.glassdoor.com/partner/jobListing.h...
# 2  Gurgaon  Gurgaon  https://www.glassdoor.com/partner/jobListing.h...
# 3  Gurgaon  Gurgaon  https://www.glassdoor.com/partner/jobListing.h...
# 4  Gurgaon  Gurgaon  https://www.glassdoor.com/partner/jobListing.h...
#
#                                             JOB_INFO
# ...

# %%
dfNDelhi.head()
# Out:
#    Unnamed: 0                                Name                   Company  \
# 0           0                        Data Analyst                      Hike
# 1           1  Business Analyst - Data Management                   Genpact
# 2           2          Global Data Senior Analyst   Boston Consulting Group
# 3           3                        Data Analyst                RELX Group
# 4           4                        Data Analyst                     Paytm
#
#         City   Location                                                Url  \
# 0  New Delhi  New Delhi  https://www.glassdoor.com/partner/jobListing.h...
# 1    Gurgaon    Gurgaon  https://www.glassdoor.com/partner/jobListing.h...
# 2  New Delhi  New Delhi  https://www.glassdoor.com/partner/jobListing.h...
# 3  New Delhi  New Delhi  https://www.glassdoor.com/partner/jobListing.h...
# 4      Noida      Noida  https://www.glassdoor.com/partner/jobListing.h...
#
#                                             JOB_INFO
# ...

# %%
dfBlr['Company'].head(30)
# Out:
# 0                                 Intrado
# 1                                  Amazon
# 2                                  Cyient
# 3                                 Siemens
# 4                                 Cargill
# 5                                   Simpl
# 6                                 Verizon
# 7                                  Luxoft
# 8                                 Siemens
# 9              Information Services Group
# 10                          GALE Partners
# 11                               Swiss Re
# 12                               Flipkart
# 13                              Unacademy
# 14                                  Capco
# 15                      Intel Corporation
# 16                          Cisco Systems
# 17                                 VMware
# 18                              Hirearchy
# 19                                DocsApp
# 20                              Capgemini
# 21                                Proziod
# ...

# %%
set(dfBlr.Company.values)
# Out:
# {' Amazon',
#  ' Capco',
#  ' Capgemini',
#  ' Cargill',
#  ' Cisco Systems',
#  ' Cyient',
#  ' DocsApp',
#  ' Flipkart',
#  ' GALE Partners',
#  ' Hirearchy',
#  ' ITC Infotech India Ltd',
#  ' Information Services Group',
#  ' Intel Corporation',
#  ' Intrado',
#  ' J.P. Morgan',
#  ' Luxoft',
#  ' Nanobi Data & Analytics',
#  ' Proziod',
#  ' Siemens',
#  ' Simpl',
#  ' Sony India Software Centre Pvt Ltd',
#  ' Swiss Re',
#  ' Unacademy',
#  ' VMware',
#  ' Vedantu',
#  ' Verizon',
#  ' Xpheno'}

# %%
Dict1 = { 
    "Delhi": list(dfNDelhi.Company.unique()),
    "Pune": list(dfPune.Company.unique()),
    "Bengaluru" : list(dfBlr.Company.unique()),
    "Gurgaon" : list(dfGur.Company.unique()),
    "Noida" : list(dfNoida.Company.unique()),
    "Hyderabad" : list(dfHyd.Company.unique())
}

# %%
dfIndia = pd.DataFrame({key:pd.Series(value) for key,value in Dict1.items()})

# %%
dfIndia
# Out:
#                                   Delhi                   Pune  \
# 0                                  Hike               Cotiviti
# 1                               Genpact                Red Hat
# 2               Boston Consulting Group         Merkle Sokrati
# 3                            RELX Group       Affinity Express
# 4                                 Paytm     Brave Venture Labs
# 5                            Eminenture             QuinStreet
# 6                                Adidas               Hexanika
# 7                  Clearwater Analytics               PubMatic
# 8                                  SSPL            CrowdStrike
# 9                             TBO Group                  Druva
# 10                                  FIS                Avalara
# 11                                  BHP        Ractus Services
# 12                              Edunuts                    FIS
# 13                          GroundTruth              Cognizant
# ...
